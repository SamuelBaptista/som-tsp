# %%
import pandas as pd
from funcs import clean_column_names

# %%
gatec = pd.read_excel('../sample_data/gatec.xlsx')

# %%
columns_to_select = [
    'cod_fazenda',
    'area_(ha)',
    'producao_(t)',
    ''
]

# %%
gatec.head()
# Out:
#   mes       bl_logist  cod_fazenda        fazenda  \
# 0   7  BL 285 DELARCO         4151    FAZ PARAISO
# 1   7  BL 285 DELARCO         4151    FAZ PARAISO
# 2   7  BL 285 DELARCO         4170   SIT SAO JOSE
# 3   7          BL.103         3092  SIT STA ELIZA
# 4   7          BL.103         3092  SIT STA ELIZA
#
#                           nome_proprietario          tipo  talhao  \
# 0                     RENATO DUCATI DELARCO    FORNECEDOR       1
# 1                     RENATO DUCATI DELARCO    FORNECEDOR       2
# 2                              WILSON COSTA    FORNECEDOR       1
# 3  MARIA CARMEN PASQUINI BAPTISTA DE AGUIAR  ARRENDAMENTO       1
# 4  MARIA CARMEN PASQUINI BAPTISTA DE AGUIAR  ARRENDAMENTO       2
#
#   estagio_de_corte variedade maturacao data_ultcorte            municipio  \
# 0                3   CTC9003   PRECOCE    2020-07-19              EMBAUBA
# 1                3   CTC9003   PRECOCE    2020-07-19              EMBAUBA
# 2                8     CTC15     MEDIA    2020-07-10  MONTE AZUL PAULISTA
# 3                3  RB966928   PRECOCE    2020-06-04         SANTA ADELIA
# 4                3  RB966928   PRECOCE    2020-06-04         SANTA ADELIA
#
#    area_(ha)  producao_(t)  dist_(km)  idade_(m)       atr
# 0       7.39         665.1       41.0  12.033333  120.7032
# 1      14.19        1277.1       41.0  12.033333  120.7032
# 2      15.39        1077.3       45.0  12.333333  120.7032
# 3       1.47        101.43       27.0  13.533333  120.6117
# 4        1.7         117.3       27.0  13.533333  120.6117

# %%
gatec = gatec.convert_dtypes()
gatec.columns = clean_column_names(gatec.columns)
